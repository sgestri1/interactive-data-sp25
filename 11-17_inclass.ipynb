# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
af = pd.read_csv('audio_features.csv', sep = ',')

# %%
af.head()
# Out:
#    Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 0           0         0.735   0.444   10   -10.519     1       0.0684
# 1           1         0.658   0.378    7    -8.300     1       0.0379
# 2           2         0.638   0.634    4    -6.582     1       0.0457
# 3           3         0.659   0.323    9   -13.425     1       0.0436
# 4           4         0.694   0.380    2   -10.307     1       0.0614
#
#    acousticness  instrumentalness  liveness  valence    tempo            type  \
# 0        0.2040          0.001200    0.1700   0.0984   97.038  audio_features
# 1        0.0593          0.000000    0.0976   0.0382  108.034  audio_features
# 2        0.1330          0.000001    0.1520   0.5190   96.953  audio_features
# 3        0.7350          0.003210    0.1160   0.1540  110.007  audio_features
# 4        0.4160          0.000008    0.1260   0.3760  120.044  audio_features
#
#                        id                                   uri  \
# ...

# %%
fig1, ax1 = plt.subplots()
mid_df = af[af['album'] == 'midnights']
lon_df = af[af['album'] == 'loneliest']
ax1.scatter(lon_df['danceability'], lon_df['valence'], label = 'Loneliest Album', color = 'orange')
ax1.scatter(mid_df['danceability'], mid_df['valence'], label = 'Midnights Album', color = 'blue')
ax1.set_xlabel('Danceability')
ax1.set_ylabel('Valence')
ax1.set_title('Relationsip between Danceability and Valence for Two Current Pop Albums')
ax1.legend()
plt.show()

# %%
fig2, ax2 = plt.subplots()
mid_val = af[af['album'] == 'midnights']['valence']
lon_val = af[af['album'] == 'loneliest']['valence']
mid_x = [1] * len(mid_val)
lon_x = [2] * len(lon_val)
mid_x_jitter = np.random.uniform(-0.10, 0.10, len(mid_x))
lon_x_jitter = np.random.uniform(-0.10, 0.10, len(lon_x))
ax2.scatter(mid_x + mid_x_jitter, mid_val, alpha = 0.4)
ax2.scatter(lon_x + lon_x_jitter, lon_val, alpha = 0.4)
ax2.set_xlim(0.5, 2.5)
# fig2.set_figheight(10)
ax2.boxplot([mid_val, lon_val])
ax2.set_xticks([1,2], ['Midnights', 'Loneliest'])
plt.show()

# %% [markdown]
# Regression notes:
# y = B1x1 + B2X2 + E
# y is the DV or dependent variable, Beta are weights and the bigger one will have more of an impact on DV, E is error
